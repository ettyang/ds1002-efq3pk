# %% [markdown]
# <a href="https://colab.research.google.com/github/ettyang/ds1002-efq3pk/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values
import matplotlib.pyplot as plt
import numpy as np
slices = np.array([56, 66, 24, 124, 47])
labels = ["US","UK","MX","CA","JP"]

# %%
plt.pie(slices, labels = labels)
plt.show()

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data
import seaborn as sns
import numpy as np
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)

# %%
n = pd.DataFrame(n)

sns.kdeplot(n)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})

# %%
for col in 'xy':
  sns.histplot(df[col], alpha=0.5)
